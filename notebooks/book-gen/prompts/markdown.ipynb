# %%
settings = {
  "subject": "The history of the Holy Grail",
  "sections_tip": "\n        the first section should tell a compelling story to catch the readers attention.\n        the last section should propose further research that the reader can do.\n        the other sections are for facts and information development.\n        ",
  "tone_of_voice": "adventure and mistery",
  "model": "gpt-3.5-turbo",
  "titles_min": 2,
  "titles_max": 4,
  "sections_min": 2,
  "sections_max": 4,
  "chapters_min": 2,
  "chapters_max": 2,
  "paragraphs_min": 2,
  "paragraphs_max": 2,
  "excerpt_length_min": 15,
  "excerpt_length_max": 30,
  "paragraph_length_min": 50,
  "paragraph_length_max": 100,
  "title": "Chasing the Holy Grail",
  "subtitle": "A Thrilling Adventure into the Enigmatic Past",
  "sections": [
    {
      "id": 1,
      "title": "The Mysterious Quest Begins",
      "excerpt": "Join our fearless adventurers as they unravel cryptic clues leading to the legendary Holy Grail, braving ancient traps and encountering enigmatic figures along the way.",
      "chapters": [
        {
          "id": 5,
          "title": "The Cryptic Map Revealed",
          "excerpt": "Follow the ancient map's mysterious symbols, guiding our adventurers through treacherous terrains towards the elusive Holy Grail.",
          "paragraphs": [
            {
              "id": 1,
              "content": "As the adventurers cautiously unfurl the ancient parchment, a rush of anticipation fills the air. The cryptic symbols etched onto the weathered map seem to pulsate with unseen energy, whispering tales of untold mysteries. Each line and curve holds the promise of leading them closer to their ultimate prize\u2014the fabled Holy Grail, said to possess unimaginable powers."
            },
            {
              "id": 2,
              "content": "With steely determination, they decipher the intricate patterns, following the map's guidance through rugged landscapes fraught with danger. Every step brings them nearer to the heart of the enigma, where legends intersect with reality. The journey towards the elusive Holy Grail is not just a physical trek but a test of their wits, resilience, and unwavering belief in the power of their quest."
            }
          ]
        },
        {
          "id": 6,
          "title": "Encounters in the Dark Forest",
          "excerpt": "Venture into the eerie depths of the Dark Forest, where shadows dance and secrets lurk, testing the courage of our brave questers.",
          "paragraphs": [
            {
              "id": 1,
              "content": "As our intrepid adventurers step into the foreboding Dark Forest, a shiver runs down their spines, sensing the ancient aura that permeates the air. The towering trees loom overhead like silent sentinels, their twisted branches casting ominous shadows that seem to shift and whisper secrets known only to the forest itself. With each cautious footfall, the undergrowth rustles with unseen movements, keeping the questers on edge as they navigate the labyrinthine paths of this mysterious realm."
            },
            {
              "id": 2,
              "content": "Eerie cries of nocturnal creatures pierce the night, adding to the unsettling ambiance of the Dark Forest as our brave adventurers press on, their torches flickering against the encroaching darkness. Strange shapes flit at the edge of their vision, elusive and ghostly, heightening the sense of otherworldly presence that permeates the ancient woods. Every step brings them deeper into the heart of the unknown, where courage is tested not only by physical dangers but by the unseen forces that dwell within the shadows, waiting to challenge their resolve."
            }
          ]
        }
      ]
    },
    {
      "id": 2,
      "title": "The Enigma of the Holy Grail",
      "excerpt": "Delve into the centuries-old myths and legends surrounding the Holy Grail, a symbol of divine power and eternal life, shrouded in mystery and intrigue.",
      "chapters": [
        {
          "id": 7,
          "title": "The Sacred Origins",
          "excerpt": "Uncover the ancient origins of the Holy Grail, tracing its mystical beginnings amidst tales of magic, miracles, and divine intervention.",
          "paragraphs": [
            {
              "id": 1,
              "content": "In the depths of time, the Holy Grail emerges from the mists of legend, its origins intertwined with the fabric of ancient beliefs and mystical traditions. Stories whisper of a sacred vessel with the power to bestow divine grace upon those deemed worthy, a chalice that has witnessed miracles and acts of transcendent wonder. The quest to trace its mystical beginnings leads back through the annals of history, where myth and reality blur into a tapestry of enigmatic tales that defy the boundaries of mortal understanding."
            },
            {
              "id": 2,
              "content": "Legends speak of the Holy Grail as a symbol of purity and eternal life, touched by the hand of destiny and imbued with the essence of spiritual truth. From the realms of magic to the realms of men, the chalice's journey unfolds amidst whispers of otherworldly origins and divine intervention. As seekers of truth delve into the sacred origins of the Grail, they are confronted with a legacy steeped in mystery and wonder, beckoning them to unravel the ancient enigmas that surround this elusive symbol of transcendent power."
            }
          ]
        },
        {
          "id": 8,
          "title": "Secrets of the Grail Keepers",
          "excerpt": "Journey into the clandestine world of the Grail Keepers, guardians of the sacred chalice, sworn to protect its secrets at any cost.",
          "paragraphs": [
            {
              "id": 1,
              "content": "As our journey delves into the clandestine world of the Grail Keepers, the air is thick with an aura of mystery and intrigue. These enigmatic figures, veiled in secrecy, stand as steadfast sentinels guarding the ancient chalice of legend. Their eyes, clouded with the weight of centuries-old secrets, betray a stern determination to protect the sacred vessel at all costs, for within its ornate curves lie the keys to transcendent power and eternal truths."
            },
            {
              "id": 2,
              "content": "Within the cloistered chambers of the Grail Keepers, shadows dance like whispers of forgotten oaths, veiling the truth of their solemn duty. Each Keeper carries the weight of centuries on their shoulders, bound by an unbreakable oath to safeguard the chalice's mysteries from unworthy hands. Their whispers echo through dimly lit corridors, hinting at the perilous consequences that await those who dare to challenge the guardians of the sacred relic, plunging into a realm where legends and reality intertwine in a dance of secrecy and sacrifice."
            }
          ]
        }
      ]
    },
    {
      "id": 3,
      "title": "The Knights Templar Connection",
      "excerpt": "Explore the fascinating link between the Knights Templar and the Holy Grail, as whispers of secret rituals and hidden treasures echo through history.",
      "chapters": [
        {
          "id": 9,
          "title": "Whispers of the Templar Code",
          "excerpt": "Decipher the cryptic symbols of the Templar Code, unveiling their connection to the enigmatic quest for the elusive Holy Grail.",
          "paragraphs": [
            {
              "id": 1,
              "content": "In the dimly lit chambers adorned with intricate symbols and ancient tapestries, the enigmatic whispers of the Templar Code echo through the ages. Each cryptic symbol etched with precision carries the weight of centuries-old secrets, a testament to the clandestine rituals and mysterious practices of the Knights Templar. As questers delve into the labyrinthine meanings of the code, a sense of profound mystery and intrigue shrouds the very air, hinting at a deeper connection to the legendary Holy Grail. The deciphering of these enigmatic symbols becomes not just a task but a journey into the heart of ancient mysteries waiting to be unveiled."
            },
            {
              "id": 2,
              "content": "As the questers meticulously unravel the layers of the Templar Code, a web of interconnected meanings and hidden truths begins to emerge, weaving a narrative that transcends time and space. Each symbol, each line, each curve, is a piece of a larger puzzle, guiding the seekers towards a revelation that promises to illuminate the enigmatic quest for the elusive Holy Grail. Within the intricate patterns of the code lie the keys to understanding the intersection of history, myth, and destiny, beckoning the brave adventurers to unlock the secrets that have remained veiled in obscurity for centuries."
            }
          ]
        },
        {
          "id": 10,
          "title": "The Templar's Last Stand",
          "excerpt": "Relive the final moments of the Knights Templar, shrouded in mystery and betrayal, as their legacy becomes intertwined with the legend of the Holy Grail.",
          "paragraphs": [
            {
              "id": 1,
              "content": "In the fading light of a tumultuous era, the Knights Templar stood on the precipice of history, their once invincible stronghold now besieged by shadows of betrayal and intrigue. The whispers of treachery echoed through the hallowed halls, mingling with the defiant resolve of those who refused to surrender to the forces that sought to extinguish their legacy. As the final hour approached, the Templars, warriors and knights of old, prepared to make their last stand, a defiant testament to their unwavering devotion to a cause that had defined them for generations."
            },
            {
              "id": 2,
              "content": "Amidst the clash of swords and the roar of flames, the Templars faced their ultimate trial, their deeds and sacrifices fated to be forever entwined with the enigmatic quest for the Holy Grail. As the dust settled on the battlefield, the legacy of the Knights Templar endured, a poignant reminder of honor and valor in the face of darkness. Their last stand became a symbol of resilience and a beacon of hope for future seekers, as the echoes of their courage continued to resonate through the annals of time, forever tied to the enduring mythology of the elusive Holy Grail."
            }
          ]
        }
      ]
    },
    {
      "id": 4,
      "title": "Unveiling the Veil of Mystery",
      "excerpt": "Embark on your own quest for truth by investigating the enduring mysteries of the Holy Grail, from Arthurian legends to historical artifacts waiting to be discovered.",
      "chapters": [
        {
          "id": 11,
          "title": "Lost Legends of Avalon",
          "excerpt": "Journey to the mystical land of Avalon, where ancient tales whisper of a connection to the Holy Grail and a hidden truth waiting to be unearthed.",
          "paragraphs": [
            {
              "id": 1,
              "content": "As the mists of time part to reveal the mystical land of Avalon, a sense of wonder and anticipation fills the hearts of those who dare to venture into its ancient realms. Legends and whispers intertwine, weaving a tapestry of enchantment and mystery that beckons the curious seeker to unlock the secrets of this fabled place. Within the verdant valleys and shimmering lakes of Avalon lie echoes of a forgotten past, where the threads of truth and myth entwine to reveal a connection to the elusive Holy Grail, a truth waiting to be unearthed by those brave enough to tread its hallowed grounds."
            },
            {
              "id": 2,
              "content": "As adventurers delve into the lost legends of Avalon, they are met with tales as old as time itself, echoing through the whispering winds and ancient stones that line the pathways of this mystical realm. The air is alive with the echoes of ancient bards and the spirits of heroes long gone, their stories merging with the very essence of Avalon itself. Each step brings them closer to the heart of the land's mysteries, where the presence of the Holy Grail is whispered to linger, a secret waiting to be revealed to those who possess the courage to seek the truth amidst the enchantment of Avalon."
            }
          ]
        },
        {
          "id": 12,
          "title": "The Enchanted Sword Excalibur",
          "excerpt": "Unravel the mystery of Excalibur, the legendary sword of King Arthur, said to hold powers linked to the Holy Grail and the fate of kingdoms.",
          "paragraphs": [
            {
              "id": 1,
              "content": "In the annals of legendary swords, none shines as brightly as Excalibur, the fabled blade of King Arthur, steeped in mystique and power. Whispers of its origins echo through the mists of time, painting a picture of a weapon forged not just of metal but of destiny itself. Said to be imbued with magical properties linked to the Holy Grail, Excalibur holds the key to the very fate of kingdoms, its gleaming blade a symbol of nobility, chivalry, and the divine right of kings. The quest to unravel the mysteries of Excalibur is not merely a search for a weapon but a journey into the heart of Arthurian legend, where myth and reality intertwine in a tapestry of epic proportions."
            },
            {
              "id": 2,
              "content": "As seekers delve into the enchanting tale of Excalibur, they are drawn into a world where sword and sorcery merge, where the line between history and myth blurs with each swing of the legendary blade. The legacy of Excalibur transcends the confines of mortal existence, its story interwoven with the very essence of King Arthur's reign and the quest for spiritual enlightenment. From the Lady of the Lake's bestowal to the sword's return to the watery depths, every aspect of Excalibur's saga holds clues to the enigmatic connection it shares with the Holy Grail, a bond that continues to captivate hearts and minds across the ages."
            }
          ]
        }
      ]
    }
  ]
}

# %%
import json

def generate_markdown(book):
    markdown = []
    
    # Title and Subtitle
    markdown.append(f"# {book['title']}")
    markdown.append(f"## {book['subtitle']}")
    markdown.append("\n")
    
    for section in book['sections']:
        # Section Title
        markdown.append(f"## {section['title']}")
        markdown.append("\n")
        
        for chapter in section.get('chapters', []):
            # Chapter Title
            markdown.append(f"### {chapter['title']}")
            markdown.append("\n")
            
            for paragraph in chapter.get('paragraphs', []):
                # Paragraph Content
                markdown.append(paragraph['content'])
                markdown.append("\n\n")
        
        markdown.append("\n")

    return "\n".join(markdown)

# %%
from IPython.display import Markdown, display
md = generate_markdown(settings)
display(Markdown(md))
# Out:
# # Chasing the Holy Grail
# ## A Thrilling Adventure into the Enigmatic Past
#
#
# ## The Mysterious Quest Begins
#
#
# ### The Cryptic Map Revealed
#
#
# As the adventurers cautiously unfurl the ancient parchment, a rush of anticipation fills the air. The cryptic symbols etched onto the weathered map seem to pulsate with unseen energy, whispering tales of untold mysteries. Each line and curve holds the promise of leading them closer to their ultimate prize—the fabled Holy Grail, said to possess unimaginable powers.
#
#
#
# With steely determination, they decipher the intricate patterns, following the map's guidance through rugged landscapes fraught with danger. Every step brings them nearer to the heart of the enigma, where legends intersect with reality. The journey towards the elusive Holy Grail is not just a physical trek but a test of their wits, resilience, and unwavering belief in the power of their quest.
#
#
#
# ### Encounters in the Dark Forest
#
#
# ...
